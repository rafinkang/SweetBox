# %%
import numpy as np
import pandas as pd
import json
import requests

# %%
#웹에 있는 json데이터 읽기
#key
#de94fab2e7564e8d9c7a4e43a6a452ba
#http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=de94fab2e7564e8d9c7a4e43a6a452ba&movieCd=20124079

# %%
dataList=[]

# %%
url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=de94fab2e7564e8d9c7a4e43a6a452ba&targetDt=201801'
for i in range(10,20):
    url2= url+str(i)
    resp=requests.get(url2)
    data=resp.json()
    print("----------",i,"-------------")
    print(data)
    dataList.append(data)
# Out:
# ---------- 10 -------------
# ...

# %%
dataList
# Out:
# [{'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#    'dailyBoxOfficeList': [{'audiAcc': '4611798',
#      'audiChange': '-5.2',
#      'audiCnt': '166737',
#      'audiInten': '-9056',
#      'movieCd': '20170590',
#      'movieNm': '1987',
#      'openDt': '2017-12-27',
#      'rank': '1',
#      'rankInten': '0',
#      'rankOldAndNew': 'OLD',
#      'rnum': '1',
#      'salesAcc': '36814262232',
#      'salesAmt': '1264934200',
#      'salesChange': '-5.1',
#      'salesInten': '-68257100',
#      'salesShare': '35.6',
#      'scrnCnt': '1080',
#      'showCnt': '4666'},
#     {'audiAcc': '11974784',
#      'audiChange': '-9.3',
#      'audiCnt': '141824',
#      'audiInten': '-14519',
#      'movieCd': '20150976',
#      'movieNm': '신과함께-죄와 벌',
#      'openDt': '2017-12-20',
#      'rank': '2',
#      'rankInten': '0',
#      'rankOldAndNew': 'OLD',
#      'rnum': '2',
#      'salesAcc': '96106073437',
#      'salesAmt': '1061472000',
#      'salesChange': '-9',
# ...

# %%
dataList[0]
# {'boxOfficeResult'}
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'dailyBoxOfficeList': [{'audiAcc': '4611798',
#     'audiChange': '-5.2',
#     'audiCnt': '166737',
#     'audiInten': '-9056',
#     'movieCd': '20170590',
#     'movieNm': '1987',
#     'openDt': '2017-12-27',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'rnum': '1',
#     'salesAcc': '36814262232',
#     'salesAmt': '1264934200',
#     'salesChange': '-5.1',
#     'salesInten': '-68257100',
#     'salesShare': '35.6',
#     'scrnCnt': '1080',
#     'showCnt': '4666'},
#    {'audiAcc': '11974784',
#     'audiChange': '-9.3',
#     'audiCnt': '141824',
#     'audiInten': '-14519',
#     'movieCd': '20150976',
#     'movieNm': '신과함께-죄와 벌',
#     'openDt': '2017-12-20',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'rnum': '2',
#     'salesAcc': '96106073437',
#     'salesAmt': '1061472000',
#     'salesChange': '-9',
#     'salesInten': '-104351200',
# ...

# %%
dataList[0]['boxOfficeResult']['boxofficeType']
# Out:
# '일별 박스오피스'

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# {'movieInfoResult': {'movieInfo': {'actors': [{'cast': '',
#      'castEn': '',
#      'peopleNm': '톰 크루즈',
#      'peopleNmEn': 'Tom Cruise'},
#     {'cast': '',
#      'castEn': '',
#      'peopleNm': '제레미 레너',
#      'peopleNmEn': 'Jeremy Renner'}],
#    'audits': [{'auditNo': '2011-F688', 'watchGradeNm': '15세이상관람가'}],
#    'companys': [{'companyCd': '20104469',
#      'companyNm': '파라마운트 픽쳐스',
#      'companyNmEn': 'Paramount Pictures',
#      'companyPartNm': '제작사'},
#     {'companyCd': '20110854',
#      'companyNm': '씨제이이앤엠(주)',
#      'companyNmEn': 'CJ ENM Corp.',
#      'companyPartNm': '배급사'},
#     {'companyCd': '20110854',
#      'companyNm': '씨제이이앤엠(주)',
#      'companyNmEn': 'CJ ENM Corp.',
#      'companyPartNm': '수입사'},
#     {'companyCd': '20104469',
#      'companyNm': '파라마운트 픽쳐스',
#      'companyNmEn': 'Paramount Pictures',
#      'companyPartNm': '제공'}],
#    'directors': [{'peopleNm': '브래드 버드', 'peopleNmEn': 'Brad Bird'}],
#    'genres': [{'genreNm': '액션'}],
# ...
